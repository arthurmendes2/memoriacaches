# %% [markdown]
# # Exemplo 5.2
#  - Na figura abaixo temos o conceito de localidade espacial ou seja cada bloco de instrução será realizado em sequencia.
#  - Na localidade espacial endereços proximos tendem a ser acessados em curto periodo de tempo.
#  - O processador irá realizar cada instruçao dos blocos de maneira sequencial
#  - Primeiro será realizado Parte 1, Os dois loops , sub-rotina 1, parte 2 e parte 3

# %%
from IPython import display
display.Image("5.2.png")

# %% [markdown]
# # Exemplo 5.3
# - Na figura abaixo temos um Program em C sobre os conceitos de localidade espacial e temporal
# - Na localidade temporal o mesmmo endereço tende a ser acessado em curto periodo de tempo
# - Na parte de localidade espacial do programa temos o calculo de media de alunos da turma sendo as instruçoes realizadas em sequênnia
# - Na parte da localidade temporal do programa temos loops ou seja acessando o mesmo endereço em curto periodo.

# %%
from IPython import display
display.Image("5.3.png")

# %% [markdown]
# # Exemplo 5.4
# - Na figura abaixo temos a organização de informaçoes processador/cache/MP
# - O Processador ira buscar as instruçoes que estão na cache e se estiver lá, ele pega e utiliza. (Rapido)
# - Caso a instruçao nao esteja na cache ele vai recorrer a MP e inves de pegar uma instrução ele vai pegar um bloco de instruçao
# - Esse Bloco sera armazenado na cache e caso o processador precise pegar essa instruçao novamente, ele ja vai recorrer a cache.

# %%
from IPython import display
display.Image("5.4.png")

# %% [markdown]
# #  Exemplo 5.5
# - Na figura abaixo temos o conceito generico de acesso
# - Processador inicia operação de leitura e coloca endereço da MP no barramento de endereços (BE)
# - a cache intercepta o endereço,interpreta o conteúdo e verifica se o dado está ou não em cache
# - se estiver temos acerto (hit) e se nao estiver temos falta (miss)
# - no acerto o dado da cache é transferido para o processador pelo BD
# - na faltaa MP é acionado para recuperar o bloco correspondente da MP e transferí-lo para cache, e também, transferir ao processador pelo BD

# %%
from IPython import display
display.Image("5.5.png")

# %% [markdown]
# # Exemplo 5.6
# - Na figura abaixo temos a organização basica de uma cache
# - para se ter o aproveitamento melhor que a MP utiliza esse modelo divido em linhas inves de bloco como é a MP]
# - são organizada em linhas de x bytes, a tag significa endereço do bloco da MP.

# %%
from IPython import display
display.Image("5.6.png")

# %% [markdown]
# # Exemplo 5.7
# -Na figura abaixo temos exemplo de organazição da cache e da MP
# - A MP é diferente, pois é organizada em blocos de X células
# - Cabe então modelos de mapeamento da MP para cache com os exemplos: direto, assosiativo

# %%
from IPython import display
display.Image("5.7.png")

# %% [markdown]
# # Exemplo 5.8
#  - Na figura abaixo temos a organização de ucp/cache/mp em um Barramento únicos
#  - Sendo esse barramento de dados, endereços e controle

# %%
from IPython import display
display.Image("5.8.png")

# %% [markdown]
# # Exemplo 5.9
# - Na figura abaixo temos o mapeamento direto
# - No Mapeamento direto cada bloco da MP tem uma linha da cache pré definida,há mais blocos do que linhas, então alguns blocos sera destinado na mesma linha.
# - Ou seja, no linha 0 terá x bytes, na linh 1 é mesmo conceito e assim vai indo.
# - No exemplo abaixo a memoria possui 64 células (64 bytes) e a cache 16 bytes, nesse caso cada linha vai poder armazenar quatro blocos.

# %%
from IPython import display
display.Image("5.9.png")
